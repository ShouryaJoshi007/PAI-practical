# %% [markdown]
# # Practical 1

# %% [markdown]
# #Name:shourya joshi
# Erollment no.2503051240140
#
# Roll no.:39

# %% [markdown]
# # Practical 1: Object-Oriented Programming, Exception Handling & File Operations
#
# This notebook covers three fundamental concepts in Python:
# 1. **Object-Oriented Programming (OOP)** - Classes, objects, inheritance, polymorphism
# 2. **Exception Handling** - Try-except blocks, custom exceptions
# 3. **File Operations** - Reading, writing, and manipulating files

# %% [markdown]
# ## Part 1: Object-Oriented Programming (OOP)
#
# OOP is a programming paradigm based on objects and classes. Key concepts:
# - **Class**: A blueprint for creating objects
# - **Object**: An instance of a class
# - **Attributes**: Variables that belong to an object
# - **Methods**: Functions that belong to a class
# - **Inheritance**: A class can inherit attributes and methods from another class
# - **Polymorphism**: Objects can take multiple forms

# %%
# Example 1: Basic Class Definition
class Student:
    """A class to represent a student"""

    def __init__(self, name, student_id, age):
        """Constructor - initializes the object"""
        self.name = name
        self.student_id = student_id
        self.age = age
        self.courses = []

    def enroll_course(self, course_name):
        """Method to enroll a student in a course"""
        self.courses.append(course_name)
        print(f"{self.name} enrolled in {course_name}")

    def display_info(self):
        """Method to display student information"""
        print(f"Name: {self.name}")
        print(f"ID: {self.student_id}")
        print(f"Age: {self.age}")
        print(f"Courses: {', '.join(self.courses) if self.courses else 'None'}")

# Create an object (instance)
student1 = Student("Alice", "S001", 20)
student1.enroll_course("Python Programming")
student1.enroll_course("Data Structures")
print("\n--- Student Information ---")
student1.display_info()
# Out:
# Alice enrolled in Python Programming
# Alice enrolled in Data Structures
#
# --- Student Information ---
# Name: Alice
# ID: S001
# Age: 20
# Courses: Python Programming, Data Structures

# %% [markdown]
# ## Part 2: Exception Handling
#
# Exception handling allows you to handle errors gracefully. Common exceptions:
# - `ValueError`: Raised when a function receives an argument of the correct type but an inappropriate value
# - `TypeError`: Raised when an operation or function is applied to an object of inappropriate type
# - `ZeroDivisionError`: Raised when the second operand in a division is zero
# - `FileNotFoundError`: Raised when a file is not found
# - `IndexError`: Raised when a sequence subscript is out of range

# %%
# Example 3: Try-Except Block
def divide_numbers(a, b):
    """Function that divides two numbers with exception handling"""
    try:
        result = a / b
        return result
    except ZeroDivisionError:
        print("Error: Cannot divide by zero!")
        return None
    except TypeError:
        print("Error: Both inputs must be numbers!")
        return None

# Test cases
print("Test 1: 10 / 2 =", divide_numbers(10, 2))
print("Test 2: 10 / 0 =", divide_numbers(10, 0))
print("Test 3: 10 / 'a' =", divide_numbers(10, 'a'))
# Out:
# Test 1: 10 / 2 = 5.0
# Error: Cannot divide by zero!
# Test 2: 10 / 0 = None
# Error: Both inputs must be numbers!
# Test 3: 10 / 'a' = None

# %%
# Example 4: Try-Except-Finally Block
def read_number_from_user():
    """Get a number from user with exception handling"""
    try:
        user_input = input("Enter a number: ")
        number = int(user_input)
        return number
    except ValueError:
        print("Error: Please enter a valid integer!")
        return None
    finally:
        print("Attempt completed!\n")

# Simulate user input for testing
import sys
from io import StringIO

# Test with valid input
print("--- Test 1: Valid input ---")
old_stdin = sys.stdin
sys.stdin = StringIO("42\n")
result = read_number_from_user()
sys.stdin = old_stdin
print(f"Result: {result}")

# %%
# Example 5: Custom Exception
class InvalidAgeError(Exception):
    """Custom exception for invalid age"""
    pass

class BankAccount:
    """Class with custom exception handling"""
    def __init__(self, account_holder, age):
        if age < 18:
            raise InvalidAgeError(f"{account_holder} must be at least 18 years old to open an account!")
        self.account_holder = account_holder
        self.age = age
        self.balance = 0

    def deposit(self, amount):
        if amount <= 0:
            raise ValueError("Deposit amount must be positive!")
        self.balance += amount
        print(f"Deposited ${amount}. New balance: ${self.balance}")

    def withdraw(self, amount):
        if amount > self.balance:
            raise ValueError("Insufficient funds!")
        self.balance -= amount
        print(f"Withdrew ${amount}. New balance: ${self.balance}")

# Test custom exception
try:
    account = BankAccount("Bob", 16)  # Will raise InvalidAgeError
except InvalidAgeError as e:
    print(f"Account creation failed: {e}")

try:
    account = BankAccount("Alice", 25)
    account.deposit(1000)
    account.withdraw(500)
    account.withdraw(2000)  # Will raise ValueError
except ValueError as e:
    print(f"Transaction error: {e}")

# %% [markdown]
# ## Part 3: File Operations
#
# File operations allow you to read from and write to files. Common modes:
# - `'r'`: Read (default)
# - `'w'`: Write (creates new file or overwrites existing)
# - `'a'`: Append (adds to end of file)
# - `'rb'`, `'wb'`: Binary read/write
# - `'x'`: Create (fails if file exists)

# %%
# Example 6: Writing to a File
# Create a sample file
filename = "sample_data.txt"

# Writing data to a file
try:
    with open(filename, 'w') as file:
        file.write("Line 1: Python is awesome!\n")
        file.write("Line 2: Exception handling is important.\n")
        file.write("Line 3: File operations are useful.\n")
    print(f"Successfully wrote to {filename}")
except IOError as e:
    print(f"Error writing to file: {e}")

# %%
# Example 7: Reading from a File
# Reading the entire file
try:
    with open(filename, 'r') as file:
        content = file.read()
    print("=== File Content (read()) ===")
    print(content)
except FileNotFoundError:
    print(f"Error: File '{filename}' not found!")
except IOError as e:
    print(f"Error reading file: {e}")

# %%
# Example 8: Reading File Line by Line
try:
    with open(filename, 'r') as file:
        lines = file.readlines()
    print("=== File Content (readlines()) ===")
    for i, line in enumerate(lines, 1):
        print(f"Line {i}: {line.strip()}")
except FileNotFoundError:
    print(f"Error: File '{filename}' not found!")

# %%
# Example 9: Appending to a File
try:
    with open(filename, 'a') as file:
        file.write("Line 4: Appending new data to the file.\n")
    print("Successfully appended to file")
except IOError as e:
    print(f"Error appending to file: {e}")

# Read and display updated content
try:
    with open(filename, 'r') as file:
        print("\n=== Updated File Content ===")
        print(file.read())
except FileNotFoundError:
    print(f"Error: File '{filename}' not found!")

# %%
# Example 10: Working with CSV Files (using lists)
csv_filename = "student_data.csv"

# Write CSV data
try:
    with open(csv_filename, 'w') as file:
        file.write("Name,ID,Age,Course\n")
        file.write("Alice,S001,20,Python\n")
        file.write("Bob,S002,22,Java\n")
        file.write("Charlie,S003,19,C++\n")
    print(f"CSV file '{csv_filename}' created successfully")
except IOError as e:
    print(f"Error creating CSV: {e}")

# Read and parse CSV data
try:
    with open(csv_filename, 'r') as file:
        lines = file.readlines()

    print("\n=== Student Data from CSV ===")
    headers = lines[0].strip().split(',')
    print(f"Headers: {headers}")
    print()

    for line in lines[1:]:
        data = line.strip().split(',')
        if len(data) == len(headers):
            record = dict(zip(headers, data))
            print(f"Name: {record['Name']}, ID: {record['ID']}, Age: {record['Age']}, Course: {record['Course']}")
except FileNotFoundError:
    print(f"Error: File '{csv_filename}' not found!")

# %% [markdown]
# ## Summary
#
# ### Object-Oriented Programming:
# - ✓ Created classes with attributes and methods
# - ✓ Used constructors (`__init__`)
# - ✓ Implemented inheritance with `super()`
# - ✓ Practiced object instantiation
#
# ### Exception Handling:
# - ✓ Used try-except blocks for error handling
# - ✓ Handled multiple exception types
# - ✓ Implemented try-except-finally blocks
# - ✓ Created and raised custom exceptions
#
# ### File Operations:
# - ✓ Wrote data to files
# - ✓ Read entire files and line-by-line
# - ✓ Appended to existing files
# - ✓ Worked with CSV format data
# - ✓ Used proper exception handling for file operations
#
# All examples demonstrate best practices including proper error handling, resource management with context managers (`with` statements), and clean code organization.

# %% [markdown]
# # Practical 2

# %% [markdown]
# #Name:shourya joshi
# Erollment no.2503051240140
#
# Roll no.:39

# %%
import pandas as pd
import numpy as np

# %%
data = {
    'Name': ['Rasna', 'Amit', 'Neha', 'Pooja', 'Ankit'],
    'Age': [22, np.nan, 25, 24, np.nan],
    'Marks': [78, 85, np.nan, 90, 88],
    'Branch': ['CSE', 'IT', 'CSE', None, 'IT']
}
df = pd.DataFrame(data)
print("Original Data:\n", df)
# Out:
# Original Data:
#      Name   Age  Marks Branch
# 0  Rasna  22.0   78.0    CSE
# 1   Amit   NaN   85.0     IT
# 2   Neha  25.0    NaN    CSE
# 3  Pooja  24.0   90.0   None
# 4  Ankit   NaN   88.0     IT

# %%
print("\nMissing Values:\n", df.isnull().sum())
# Out:
# Missing Values:
#  Name      0
# Age       2
# Marks     1
# Branch    1
# dtype: int64

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())
df['Marks'] = df['Marks'].fillna(df['Marks'].median())
df['Branch'] = df['Branch'].fillna('Unknown')
df
# Out:
#     Name        Age  Marks   Branch
# 0  Rasna  22.000000   78.0      CSE
# 1   Amit  23.666667   85.0       IT
# 2   Neha  25.000000   86.5      CSE
# 3  Pooja  24.000000   90.0  Unknown
# 4  Ankit  23.666667   88.0       IT

# %%
df.drop_duplicates(inplace=True)

df['Age'] = df['Age'].astype(int)
df
# Out:
#     Name  Age  Marks   Branch
# 0  Rasna   22   78.0      CSE
# 1   Amit   23   85.0       IT
# 2   Neha   25   86.5      CSE
# 3  Pooja   24   90.0  Unknown
# 4  Ankit   23   88.0       IT

# %%
df['Result'] = np.where(df['Marks'] >= 40, 'Pass', 'Fail')
print(df)
# Out:
#     Name  Age  Marks   Branch Result
# 0  Rasna   22   78.0      CSE   Pass
# 1   Amit   23   85.0       IT   Pass
# 2   Neha   25   86.5      CSE   Pass
# 3  Pooja   24   90.0  Unknown   Pass
# 4  Ankit   23   88.0       IT   Pass

# %%
df.rename(columns={'Marks': 'Score'}, inplace=True)

print("\nStatistical Summary:\n", df.describe())

avg_score = df.groupby('Branch')['Score'].mean()
print("\nAverage Score by Branch:\n", avg_score)

high_scorers = df[df['Score'] > 80]
print("\nStudents Scoring Above 80:\n", high_scorers)


print("\nMax Score:", np.max(df['Score']))
print("Min Score:", np.min(df['Score']))
print("Mean Score:", np.mean(df['Score']))

print("Standard Deviation:", np.std(df['Score']))


print("\nCleaned and Transformed Data:\n", df)
# Out:
# Statistical Summary:
#               Age      Score
# count   5.000000   5.000000
# mean   23.400000  85.500000
# std     1.140175   4.582576
# min    22.000000  78.000000
# 25%    23.000000  85.000000
# 50%    23.000000  86.500000
# 75%    24.000000  88.000000
# max    25.000000  90.000000
#
# Average Score by Branch:
#  Branch
# CSE        82.25
# IT         86.50
# Unknown    90.00
# Name: Score, dtype: float64
#
# Students Scoring Above 80:
#      Name  Age  Score   Branch Result
# 1   Amit   23   85.0       IT   Pass
# 2   Neha   25   86.5      CSE   Pass
# 3  Pooja   24   90.0  Unknown   Pass
# 4  Ankit   23   88.0       IT   Pass
#
# Max Score: 90.0
# Min Score: 78.0
# Mean Score: 85.5
# Standard Deviation: 4.09878030638384
#
# Cleaned and Transformed Data:
#      Name  Age  Score   Branch Result
# 0  Rasna   22   78.0      CSE   Pass
# 1   Amit   23   85.0       IT   Pass
# 2   Neha   25   86.5      CSE   Pass
# 3  Pooja   24   90.0  Unknown   Pass
# ...

# %% [markdown]
# # Practical 3

# %% [markdown]
# #Name:shourya joshi
# Erollment no.2503051240140
#
# Roll no.:39

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

X, y = load_iris(return_X_y=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)
X_train.shape, X_test.shape
# Out:
# ((105, 4), (45, 4))

# %%
model = LogisticRegression(max_iter=200)
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 1.0
# Confusion Matrix:
# [[19  0  0]
#  [ 0 13  0]
#  [ 0  0 13]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %%
from sklearn.datasets import load_diabetes
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

X, y = load_diabetes(return_X_y=True)

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

reg_model = LinearRegression()
reg_model.fit(X_train, y_train)

y_pred = reg_model.predict(X_test)

print("MAE:", mean_absolute_error(y_test, y_pred))
mse = mean_squared_error(y_test, y_pred)
print("MSE:", mse)
print("RMSE:", np.sqrt(mse))
print("R² Score:", r2_score(y_test, y_pred))
# Out:
# MAE: 41.91937845679274
# MSE: 2821.750981001311
# RMSE: 53.120156070942706
# R² Score: 0.4772897164322617

# %% [markdown]
# # Practical 4

# %% [markdown]
# #Name:shourya joshi
# Erollment no.2503051240140
#
# Roll no.:39

# %%
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

# %%
X, y = make_blobs(n_samples=200, centers=3, random_state=42)
df = pd.DataFrame(X, columns=['Feature1', 'Feature2'])
print(df.head())
# Out:
#    Feature1  Feature2
# 0  6.505653  2.447003
# 1 -5.128943  9.836189
# 2 -6.891874 -7.777364
# 3 -8.327712 -8.287573
# 4 -7.468992 -6.030507

# %%
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(X)

df['Cluster'] = kmeans.labels_
print(df.head())

print("Cluster Centers:")
print(kmeans.cluster_centers_)
# Out:
#    Feature1  Feature2  Cluster
# 0  6.505653  2.447003        2
# 1 -5.128943  9.836189        0
# 2 -6.891874 -7.777364        1
# 3 -8.327712 -8.287573        1
# 4 -7.468992 -6.030507        1
# Cluster Centers:
# [[-2.65882129  8.95756821]
#  [-6.74539381 -6.85144337]
#  [ 4.63218228  2.10121377]]

# %%
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

dbscan = DBSCAN(eps=0.5, min_samples=5)
dbscan.fit(X_scaled)

df['DBSCAN_Cluster'] = dbscan.labels_
print(df.head())

noise_points = df[df['DBSCAN_Cluster'] == -1]
print("Number of Noise Points:", len(noise_points))
# Out:
#    Feature1  Feature2
# 0  6.505653  2.447003
# 1 -5.128943  9.836189
# 2 -6.891874 -7.777364
# 3 -8.327712 -8.287573
# 4 -7.468992 -6.030507
#    Feature1  Feature2  Cluster
# 0  6.505653  2.447003        2
# 1 -5.128943  9.836189        0
# 2 -6.891874 -7.777364        1
# 3 -8.327712 -8.287573        1
# 4 -7.468992 -6.030507        1
# Cluster Centers:
# [[-2.65882129  8.95756821]
#  [-6.74539381 -6.85144337]
#  [ 4.63218228  2.10121377]]
#    Feature1  Feature2  Cluster  DBSCAN_Cluster
# 0  6.505653  2.447003        2               0
# 1 -5.128943  9.836189        0               1
# 2 -6.891874 -7.777364        1               2
# 3 -8.327712 -8.287573        1               2
# 4 -7.468992 -6.030507        1               2
# Number of Noise Points: 0

# %%
import matplotlib.pyplot as plt

# ----------- KMEANS VISUALIZATION -----------

plt.figure(figsize=(6,5))
plt.scatter(df['Feature1'], df['Feature2'], c=df['Cluster'], cmap='viridis')
plt.scatter(kmeans.cluster_centers_[:,0],
            kmeans.cluster_centers_[:,1],
            s=200, c='red', marker='X', label='Centroids')

plt.title("K-Means Clustering")
plt.xlabel("Feature1")
plt.ylabel("Feature2")
plt.legend()
plt.show()


# ----------- DBSCAN VISUALIZATION -----------

plt.figure(figsize=(6,5))
plt.scatter(df['Feature1'], df['Feature2'], c=df['DBSCAN_Cluster'], cmap='plasma')

# Highlight noise points
noise = df[df['DBSCAN_Cluster'] == -1]
plt.scatter(noise['Feature1'], noise['Feature2'],
            c='black', marker='x', label='Noise')

plt.title("DBSCAN Clustering")
plt.xlabel("Feature1")
plt.ylabel("Feature2")
plt.legend()
plt.show()

# %% [markdown]
# # Practical 5

# %% [markdown]
# #Name:shourya joshi
# Erollment no.2503051240140
#
# Roll no.:39

# %%
from sklearn.linear_model import LinearRegression
import pickle
import numpy as np
from flask import Flask, request, render_template

# STEP 1: Train and Save Model
X = np.array([[1], [2], [3], [4], [5]])
y = np.array([2, 4, 6, 8, 10])

model = LinearRegression()
model.fit(X, y)

with open("model.pkl", "wb") as file:
    pickle.dump(model, file)
print("Model saved successfully")
# Out:
# Model saved successfully

# %%
import os

# STEP 3: Create HTML File (This would typically be in 'templates/index.html')
# For demonstration, this is shown here as a string, but in a real Flask app,
# it would be a separate file.
html_content = """
<!DOCTYPE html>
<html>
<head>
    <title>ML Model Deployment</title>
</head>
<body>
    <h2>Linear Regression Model</h2>
    <form action="/predict" method="post">
        Enter value:
        <input type="text" name="value" required>
        <button type="submit">Predict</button>
    </form>
    <h3>{{ result }}</h3>
</body>
</html>
"""

# Create the 'templates' directory if it doesn't exist
if not os.path.exists('templates'):
    os.makedirs('templates')

# Save the HTML content to index.html inside the templates folder
with open('templates/index.html', 'w') as f:
    f.write(html_content)

print('templates/index.html created successfully.')
# Out:
# templates/index.html created successfully.

# %%
# Install flask-ngrok and pyngrok
# !pip install flask-ngrok pyngrok -qq

# %%
from flask import Flask, request, render_template
import pickle
from pyngrok import ngrok, conf
from google.colab import userdata # Import userdata for secrets

# STEP 2: Create Flask Application
app = Flask(__name__)

# Load trained model
model = pickle.load(open("model.pkl", "rb"))

@app.route("/")
def home():
    return render_template("index.html")

@app.route("/predict", methods=["POST"])
def predict():
    value = float(request.form["value"])
    prediction = model.predict([[value]])
    return render_template("index.html", result=f"Predicted Output: {prediction[0]}")


print("Starting ngrok tunnel...")
ngrok.kill() # Close any existing tunnels
tunnel = ngrok.connect(7000) # Connect ngrok to Flask's default port, changed from 5000 to 8000
public_url = tunnel.public_url
print(f"* Ngrok Tunnel URL: {public_url}")
print("You can access your Flask app at this URL.")

# Run Flask app (blocking operation, must be the last line in the cell)
app.run(port=7000, use_reloader=False) # Changed port from 5000 to 8000
# Out:
# Starting ngrok tunnel...
# * Ngrok Tunnel URL: https://genuine-bud-overably.ngrok-free.dev
# You can access your Flask app at this URL.
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:7000
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug:127.0.0.1 - - [28/Apr/2026 07:50:35] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [28/Apr/2026 07:50:36] "GET /favicon.ico HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [28/Apr/2026 07:51:05] "POST /predict HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [28/Apr/2026 07:51:24] "POST /predict HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [28/Apr/2026 07:53:21] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [28/Apr/2026 07:53:22] "GET /favicon.ico HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [28/Apr/2026 07:57:05] "GET / HTTP/1.1" 200 -
# ...

# %%
from pyngrok import ngrok
from google.colab import userdata

print("Starting ngrok tunnel...")

# Kill any existing ngrok tunnels
ngrok.kill()

# Set your ngrok authtoken from Colab secrets
# Replace "NGROK_AUTH_TOKEN" with the name of your secret if different
ngrok.set_auth_token(userdata.get("NGROK_AUTH_TOKEN"))

# Connect ngrok to the Flask app's port (which is 8000 in cell 069cbe4e)
tunnel = ngrok.connect(7000)
public_url = tunnel.public_url
print(f"* Ngrok Tunnel URL: {public_url}")
print("You can access your Flask app at this URL.")
# Out:
# Starting ngrok tunnel...
# * Ngrok Tunnel URL: https://genuine-bud-overably.ngrok-free.dev
# You can access your Flask app at this URL.

# %% [markdown]
# # Practical 6

# %% [markdown]
# #Name:shourya joshi
# Erollment no.2503051240140
#
# Roll no.:39

# %% [markdown]
# #Practical-6
#
# Ensemble Learning Models in Scikit-Learn
#
# Aim:o implement Random Forest, Gradient Boosting, and Stacking ensemble
# models and evaluate their performance.

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier, StackingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

# %%
X, y = load_breast_cancer(return_X_y=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# A: Random Forest Classifier

# %%
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
rf_pred = rf_model.predict(X_test)
print("Random Forest Accuracy:", accuracy_score(y_test, rf_pred))
# Out:
# Random Forest Accuracy: 0.9707602339181286

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(y_test, rf_pred)

disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()

plt.title("Confusion Matrix - Random Forest")
plt.show()

# %% [markdown]
# B: Gradient Boosting Classifier

# %%
gb_model = GradientBoostingClassifier(n_estimators=100,
learning_rate=0.1)
gb_model.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier()

# %%
gb_pred = gb_model.predict(X_test)
print("Gradient Boosting Accuracy:", accuracy_score(y_test, gb_pred))
# Out:
# Gradient Boosting Accuracy: 0.9590643274853801

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm_gb = confusion_matrix(y_test, gb_pred)

disp = ConfusionMatrixDisplay(confusion_matrix=cm_gb)
disp.plot()

plt.title("Confusion Matrix - Gradient Boosting")
plt.show()

# %% [markdown]
# C: Stacking Classifier

# %%
estimators = [
    ('rf', RandomForestClassifier(n_estimators=50, random_state=42)),
    ('svm', SVC(probability=True))
]

# %%
stack_model = StackingClassifier(
    estimators=estimators,
    final_estimator=LogisticRegression()
)

# %%
stack_model.fit(X_train, y_train)
stack_pred = stack_model.predict(X_test)
print("Stacking Model Accuracy:", accuracy_score(y_test, stack_pred))
# Out:
# Stacking Model Accuracy: 0.9707602339181286

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

cm_stack = confusion_matrix(y_test, stack_pred)

disp = ConfusionMatrixDisplay(confusion_matrix=cm_stack)
disp.plot()

plt.title("Confusion Matrix - Stacking Classifier")
plt.show()

# %%
models = ["Random Forest", "Gradient Boosting", "Stacking"]
accuracies = [
    accuracy_score(y_test, rf_pred),
    accuracy_score(y_test, gb_pred),
    accuracy_score(y_test, stack_pred)
]

plt.figure()
plt.bar(models, accuracies)
plt.ylabel("Accuracy")
plt.title("Model Comparison")
plt.show()

# %% [markdown]
# # Practical 7

# %% [markdown]
# #Name:shourya joshi
# Erollment no.2503051240140
#
# Roll no.:39

# %%
import pandas as pd
import numpy as np
data = {
'Age': [22, 25, 30, 35, 40],
'Salary': [30000, 50000, 60000, 80000, 100000],
'City': ['Delhi', 'Mumbai', 'Delhi', 'Pune', 'Mumbai'],
'Purchased': [0, 1, 0, 1, 1]
}
df = pd.DataFrame(data)
print(df)
# Out:
#    Age  Salary    City  Purchased
# 0   22   30000   Delhi          0
# 1   25   50000  Mumbai          1
# 2   30   60000   Delhi          0
# 3   35   80000    Pune          1
# 4   40  100000  Mumbai          1

# %%
df_encoded = pd.get_dummies(df, columns=['City'])
print(df_encoded)
# Out:
#    Age  Salary  Purchased  City_Label  City_Delhi  City_Mumbai  City_Pune
# 0   22   30000          0           0        True        False      False
# 1   25   50000          1           1       False         True      False
# 2   30   60000          0           0        True        False      False
# 3   35   80000          1           2       False        False       True
# 4   40  100000          1           1       False         True      False

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df_encoded[['Age', 'Salary']] = scaler.fit_transform(
df_encoded[['Age', 'Salary']]
)
print(df_encoded)
# Out:
#         Age    Salary  Purchased  City_Label  City_Delhi  City_Mumbai  \
# 0 -1.286384 -1.406930          0           0        True        False
# 1 -0.826961 -0.579324          1           1       False         True
# 2 -0.061256 -0.165521          0           0        True        False
# 3  0.704448  0.662085          1           2       False        False
# 4  1.470153  1.489691          1           1       False         True
#
#    City_Pune
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False

# %%
from sklearn.preprocessing import MinMaxScaler
minmax = MinMaxScaler()
df_encoded [['Age', 'Salary']] = minmax.fit_transform(
df_encoded [['Age', 'Salary']]
)
print(df_encoded)
# Out:
#         Age    Salary  Purchased  City_Label  City_Delhi  City_Mumbai  \
# 0  0.000000  0.000000          0           0        True        False
# 1  0.166667  0.285714          1           1       False         True
# 2  0.444444  0.428571          0           0        True        False
# 3  0.722222  0.714286          1           2       False        False
# 4  1.000000  1.000000          1           1       False         True
#
#    City_Pune
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False

# %%
correlation = df_encoded.corr()
print(correlation['Purchased'])
# Out:
# Age            0.550172
# Salary         0.641951
# Purchased      1.000000
# City_Label     0.872872
# City_Delhi    -1.000000
# City_Mumbai    0.666667
# City_Pune      0.408248
# Name: Purchased, dtype: float64

# %%
from sklearn.feature_selection import SelectKBest, chi2
X = df_encoded.drop('Purchased', axis=1)
y = df_encoded['Purchased']
selector = SelectKBest(score_func=chi2, k = 2)
X_new = selector.fit_transform(abs(X), y)
print("Selected Features Shape:", X_new.shape)
print(X_new)
# Out:
# Selected Features Shape: (5, 2)
# [[0. 1.]
#  [1. 0.]
#  [0. 1.]
#  [2. 0.]
#  [1. 0.]]

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
model.fit(X, y)
importances = model.feature_importances_
for feature, importance in zip(X.columns, importances):
    print(feature, ":", importance)
# Out:
# Age : 0.16452991452991456
# Salary : 0.2000915750915751
# City_Label : 0.25931013431013433
# City_Delhi : 0.19902319902319904
# City_Mumbai : 0.16804029304029305
# City_Pune : 0.009004884004884004

# %% [markdown]
# # Practical 8

# %% [markdown]
# #Name:shourya joshi
# Erollment no.2503051240140
#
# Roll no.:39

# %% [markdown]
# #Practical 8
# Text Classification using RNN
#
# Aim:
# To implement text classification using a Recurrent Neural Network
# (RNN) for sentiment analysis.
#
# Link: https://colab.research.google.com/drive/1o8QMQSC08_veJm4dqyZ21F1IdiIzJAqu?usp=sharing

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
texts = [
    "I love this movie",
    "This film is terrible",
    "Amazing experience",
    "Worst movie ever",
    "I enjoyed the film",
    "I hate this movie"
]
labels = [1, 0, 1, 0, 1, 0]   # 1 = Positive, 0 = Negative

# %%
tokenizer = Tokenizer(num_words=1000)
tokenizer.fit_on_texts(texts)
sequences = tokenizer.texts_to_sequences(texts)

# %%
max_len = 5
X = pad_sequences(sequences, maxlen=max_len)
y = np.array(labels)

# %%
model = Sequential()
model.add(Embedding(input_dim=1000, output_dim=16,
input_length=max_len))
model.add(SimpleRNN(32))
model.add(Dense(1, activation='sigmoid'))
model.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)
model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn (SimpleRNN)          │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Practical 9

# %% [markdown]
# #Name:shourya joshi
# Erollment no.2503051240140
#
# Roll no.:39

# %% [markdown]
# #Practical 9
#  Image Classification using CNN
# Aim:
# To implement a Convolutional Neural Network (CNN) for image
# classification using TensorFlow/Keras.

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# %%
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()
# Normalize pixel values
X_train = X_train / 255.0
X_test = X_test / 255.0
# Reshape data (CNN expects 4D input)
X_train = X_train.reshape(-1, 28, 28, 1)
X_test = X_test.reshape(-1, 28, 28, 1)
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
model = Sequential()
model.add(Conv2D(32, (3,3), activation='relu', input_shape=(28,28,1)))
model.add(MaxPooling2D((2,2)))
model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPooling2D((2,2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(10, activation='softmax'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model.fit(X_train, y_train, epochs=5, batch_size=64)
# Out:
# Epoch 1/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 51s 52ms/step - accuracy: 0.9532 - loss: 0.1556
# Epoch 2/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 49s 52ms/step - accuracy: 0.9857 - loss: 0.0464
# Epoch 3/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 48s 51ms/step - accuracy: 0.9906 - loss: 0.0310
# Epoch 4/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 47s 50ms/step - accuracy: 0.9922 - loss: 0.0241
# Epoch 5/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 48s 52ms/step - accuracy: 0.9944 - loss: 0.0178

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print("Test Accuracy:", test_accuracy)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.9914 - loss: 0.0307
# Test Accuracy: 0.9914000034332275

# %%
prediction = model.predict(X_test[:1])
print("Predicted Digit:", np.argmax(prediction))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Predicted Digit: 7

# %% [markdown]
# # Practical 10

# %% [markdown]
# #Name:shourya joshi
# Erollment no.2503051240140
#
# Roll no.:39

# %% [markdown]
# #Practical 10
# Build and Train a Simple Deep Learning Model
#
# Aim:
# To build a simple deep neural network (DNN) for classification and train
# it on a dataset.

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris

# %%
#Load Iris dataset
data = load_iris()
X = data.data
       # Features
y = data.target
     # Labels
# One-hot encode target labels
y = to_categorical(y, num_classes=3)
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
model = Sequential()
model.add(Dense(16, input_dim=4, activation='relu'))  # Input layer + hiddenlayer
model.add(Dense(12, activation='relu'))               # Hidden layer
model.add(Dense(3, activation='softmax'))             # Output layer for 3 classes

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history=model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=5,
    validation_split=0.2
)
# Out:
# Epoch 1/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.6667 - loss: 0.8843 - val_accuracy: 0.8571 - val_loss: 0.8164
# Epoch 2/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7619 - loss: 0.7838 - val_accuracy: 0.9048 - val_loss: 0.7397
# Epoch 3/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8810 - loss: 0.7106 - val_accuracy: 0.9524 - val_loss: 0.6881
# Epoch 4/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9048 - loss: 0.6573 - val_accuracy: 0.9524 - val_loss: 0.6470
# Epoch 5/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8571 - loss: 0.6156 - val_accuracy: 0.9524 - val_loss: 0.6074
# Epoch 6/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9643 - loss: 0.5731 - val_accuracy: 0.9524 - val_loss: 0.5840
# Epoch 7/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9286 - loss: 0.5372 - val_accuracy: 0.9524 - val_loss: 0.5426
# Epoch 8/50
# ...
